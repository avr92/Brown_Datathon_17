# %%
import pandas as pd

ta_data = pd.read_csv("tp_data.csv")
ta_data.head()
# Out:
#    user_id         day  gender  p_sessionActivity  p_AddToCart  \
# 0        1  2017-01-10       1                  1            0
# 1        2  2017-01-16       1                  0            0
# 2        3  2016-12-13       0                 53            0
# 3        4  2016-11-01       1                  0            0
# 4        5  2016-12-31       1                  0            0
#
#   p_trafficChannel  p_sessionDuration  p_pageViews  daysToCheckin  osType  \
# 0                O                 73            1            NaN       8
# 1                O                234            4            NaN       7
# 2                O                341            5          123.0       7
# 3                O                778            1            NaN       7
# 4                O                 34            1            NaN       7
#
#   osTypeName  daysFromPreviousVisit  p_TotalPrice  isExclusiveMember  \
# ...

# %%
ta_data = pd.read_csv("tp_data.csv", na_values=['NA'])
ta_data.describe()
# Out:
#               user_id          gender  p_sessionActivity     p_AddToCart  \
# count  1000000.000000  1000000.000000     1000000.000000  1000000.000000
# mean    500000.500000        0.417604           9.377818        0.009314
# std     288675.278932        0.493164          31.439726        0.096059
# min          1.000000        0.000000           0.000000        0.000000
# 25%     250000.750000        0.000000           0.000000        0.000000
# 50%     500000.500000        0.000000           1.000000        0.000000
# 75%     750000.250000        1.000000           6.000000        0.000000
# max    1000000.000000        1.000000        6750.000000        1.000000
#
#        p_sessionDuration     p_pageViews  daysToCheckin          osType  \
# count     1000000.000000  1000000.000000  201182.000000  1000000.000000
# mean         3587.055447        6.443328      68.297914        8.094221
# std          9564.218798       12.362642      72.976265        1.803939
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(ta_data.dropna(), hue='BookingPurchase')
